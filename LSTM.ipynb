# %%
import gzip
from sklearn.model_selection import train_test_split
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import Functions

# %%
with gzip.open('cleaned_data.zip','rb') as file:
    feature_data = pd.read_csv(file,index_col=[0,1])

with gzip.open('new_label_data.zip','rb') as file:
    new_label_data = pd.read_csv(file,index_col=[0,1])

data = pd.concat([feature_data,new_label_data],join='inner',ignore_index=False,axis=1)


X_train, X_test, Y_train, Y_test = Functions.splitdata(data,0.1)

# %%
print(feature_data.shape)
print(new_label_data.value_counts())
# Out:
# (334047, 50)
# Status
# 1         76307
# 0         76282
# 6         59461
# 4         37162
# 2         21197
# 3         11255
# 5          9891
# dtype: int64

# %%
X_train = tf.reshape(X_train,(-1,5,10))
X_test = tf.reshape(X_test,(-1,5,10))

# %%
input_dim = 10
batch_size = int(len(X_train)//10000)
units = 128
output_size = 7  # labels are from 0 to 6

# Build the RNN model
def build_model():
    lstm_layer = keras.layers.LSTM(units, input_shape=(None,input_dim))
    model = keras.models.Sequential(
        [
            lstm_layer,
            keras.layers.Dropout(0.3),
            keras.layers.BatchNormalization(),
            keras.layers.Dense(128, activation='relu'),
            keras.layers.Dense(output_size, activation='softmax'),
        ]
    )
    return model

# %%
model = build_model()
#model.summary()
model.compile(
    loss=keras.losses.SparseCategoricalCrossentropy(),
    optimizer="Adam",
    metrics=["accuracy"]
)
LSTM_model = model.fit(X_train, Y_train, validation_data=(X_test, Y_test), batch_size=batch_size, epochs=50, verbose=1)
# Out:
# Epoch 1/50
# 10094/10094 [==============================] - 62s 6ms/step - loss: 1.3020 - accuracy: 0.5186 - val_loss: 1.1131 - val_accuracy: 0.5928
# Epoch 2/50
# 10094/10094 [==============================] - 59s 6ms/step - loss: 1.1232 - accuracy: 0.5921 - val_loss: 1.0035 - val_accuracy: 0.6388
# Epoch 3/50
# 10094/10094 [==============================] - 59s 6ms/step - loss: 1.0499 - accuracy: 0.6195 - val_loss: 0.9346 - val_accuracy: 0.6640
# Epoch 4/50
# 10094/10094 [==============================] - 59s 6ms/step - loss: 0.9956 - accuracy: 0.6392 - val_loss: 0.9040 - val_accuracy: 0.6757
# Epoch 5/50
# 10094/10094 [==============================] - 60s 6ms/step - loss: 0.9549 - accuracy: 0.6544 - val_loss: 0.8711 - val_accuracy: 0.6877
# Epoch 6/50
# 10094/10094 [==============================] - 59s 6ms/step - loss: 0.9226 - accuracy: 0.6663 - val_loss: 0.8414 - val_accuracy: 0.6970
# Epoch 7/50
# 10094/10094 [==============================] - 59s 6ms/step - loss: 0.8959 - accuracy: 0.6762 - val_loss: 0.8088 - val_accuracy: 0.7085
# Epoch 8/50
# 10094/10094 [==============================] - 59s 6ms/step - loss: 0.8691 - accuracy: 0.6869 - val_loss: 0.7849 - val_accuracy: 0.7162
# Epoch 9/50
# 10094/10094 [==============================] - 60s 6ms/step - loss: 0.8509 - accuracy: 0.6935 - val_loss: 0.7657 - val_accuracy: 0.7255
# Epoch 10/50
# 10094/10094 [==============================] - 62s 6ms/step - loss: 0.8299 - accuracy: 0.7023 - val_loss: 0.7636 - val_accuracy: 0.7286
# Epoch 11/50
# 10094/10094 [==============================] - 61s 6ms/step - loss: 0.8171 - accuracy: 0.7071 - val_loss: 0.7360 - val_accuracy: 0.7360
# Epoch 12/50
# 10094/10094 [==============================] - 61s 6ms/step - loss: 0.8113 - accuracy: 0.7093 - val_loss: 0.7401 - val_accuracy: 0.7339
# Epoch 13/50
# 10094/10094 [==============================] - 63s 6ms/step - loss: 0.7936 - accuracy: 0.7169 - val_loss: 0.7276 - val_accuracy: 0.7416
# Epoch 14/50
# 10094/10094 [==============================] - 63s 6ms/step - loss: 0.7806 - accuracy: 0.7210 - val_loss: 0.7252 - val_accuracy: 0.7414
# Epoch 15/50
# 10094/10094 [==============================] - 63s 6ms/step - loss: 0.7705 - accuracy: 0.7248 - val_loss: 0.7050 - val_accuracy: 0.7503
# Epoch 16/50
# 10094/10094 [==============================] - 64s 6ms/step - loss: 0.7593 - accuracy: 0.7288 - val_loss: 0.7024 - val_accuracy: 0.7491
# Epoch 17/50
# 10094/10094 [==============================] - 64s 6ms/step - loss: 0.7515 - accuracy: 0.7323 - val_loss: 0.6868 - val_accuracy: 0.7580
# Epoch 18/50
# 10094/10094 [==============================] - 63s 6ms/step - loss: 0.7468 - accuracy: 0.7334 - val_loss: 0.6850 - val_accuracy: 0.7574
# Epoch 19/50
# 10094/10094 [==============================] - 63s 6ms/step - loss: 0.7360 - accuracy: 0.7380 - val_loss: 0.6813 - val_accuracy: 0.7592
# Epoch 20/50
# 10094/10094 [==============================] - 63s 6ms/step - loss: 0.7324 - accuracy: 0.7403 - val_loss: 0.6778 - val_accuracy: 0.7600
# Epoch 21/50
# 10094/10094 [==============================] - 62s 6ms/step - loss: 0.7266 - accuracy: 0.7411 - val_loss: 0.6658 - val_accuracy: 0.7647
# Epoch 22/50
# 10094/10094 [==============================] - 61s 6ms/step - loss: 0.7169 - accuracy: 0.7460 - val_loss: 0.6669 - val_accuracy: 0.7651
# Epoch 23/50
# 10094/10094 [==============================] - 54s 5ms/step - loss: 0.7118 - accuracy: 0.7478 - val_loss: 0.6577 - val_accuracy: 0.7700
# Epoch 24/50
# 10094/10094 [==============================] - 56s 6ms/step - loss: 0.7023 - accuracy: 0.7502 - val_loss: 0.6626 - val_accuracy: 0.7651
# Epoch 25/50
# 10094/10094 [==============================] - 56s 6ms/step - loss: 0.6986 - accuracy: 0.7518 - val_loss: 0.6397 - val_accuracy: 0.7775
# Epoch 26/50
# 10094/10094 [==============================] - 57s 6ms/step - loss: 0.6972 - accuracy: 0.7529 - val_loss: 0.6483 - val_accuracy: 0.7729
# Epoch 27/50
# 10094/10094 [==============================] - 58s 6ms/step - loss: 0.6931 - accuracy: 0.7543 - val_loss: 0.6433 - val_accuracy: 0.7713
# Epoch 28/50
# 10094/10094 [==============================] - 57s 6ms/step - loss: 0.6857 - accuracy: 0.7570 - val_loss: 0.6311 - val_accuracy: 0.7798
# Epoch 29/50
# 10094/10094 [==============================] - 56s 6ms/step - loss: 0.6785 - accuracy: 0.7594 - val_loss: 0.6367 - val_accuracy: 0.7783
# Epoch 30/50
# 10094/10094 [==============================] - 56s 6ms/step - loss: 0.6783 - accuracy: 0.7598 - val_loss: 0.6416 - val_accuracy: 0.7744
# Epoch 31/50
# 10094/10094 [==============================] - 57s 6ms/step - loss: 0.6782 - accuracy: 0.7592 - val_loss: 0.6440 - val_accuracy: 0.7754
# Epoch 32/50
# 10094/10094 [==============================] - 57s 6ms/step - loss: 0.6695 - accuracy: 0.7641 - val_loss: 0.6461 - val_accuracy: 0.7753
# Epoch 33/50
# 10094/10094 [==============================] - 57s 6ms/step - loss: 0.6678 - accuracy: 0.7624 - val_loss: 0.6231 - val_accuracy: 0.7814
# Epoch 34/50
# 10094/10094 [==============================] - 57s 6ms/step - loss: 0.6640 - accuracy: 0.7648 - val_loss: 0.6225 - val_accuracy: 0.7836
# Epoch 35/50
# 10094/10094 [==============================] - 57s 6ms/step - loss: 0.6615 - accuracy: 0.7663 - val_loss: 0.6234 - val_accuracy: 0.7835
# Epoch 36/50
# 10094/10094 [==============================] - 57s 6ms/step - loss: 0.6587 - accuracy: 0.7676 - val_loss: 0.6265 - val_accuracy: 0.7813
# Epoch 37/50
# 10094/10094 [==============================] - 57s 6ms/step - loss: 0.6577 - accuracy: 0.7673 - val_loss: 0.6196 - val_accuracy: 0.7842
# Epoch 38/50
# 10094/10094 [==============================] - 58s 6ms/step - loss: 0.6600 - accuracy: 0.7660 - val_loss: 0.6187 - val_accuracy: 0.7850
# Epoch 39/50
# 10094/10094 [==============================] - 57s 6ms/step - loss: 0.6550 - accuracy: 0.7683 - val_loss: 0.6221 - val_accuracy: 0.7864
# Epoch 40/50
# 10094/10094 [==============================] - 57s 6ms/step - loss: 0.6527 - accuracy: 0.7693 - val_loss: 0.6230 - val_accuracy: 0.7839
# Epoch 41/50
# 10094/10094 [==============================] - 57s 6ms/step - loss: 0.6482 - accuracy: 0.7716 - val_loss: 0.6059 - val_accuracy: 0.7911
# Epoch 42/50
# 10094/10094 [==============================] - 56s 6ms/step - loss: 0.6475 - accuracy: 0.7715 - val_loss: 0.6058 - val_accuracy: 0.7896
# Epoch 43/50
# 10094/10094 [==============================] - 56s 6ms/step - loss: 0.6418 - accuracy: 0.7741 - val_loss: 0.6027 - val_accuracy: 0.7895
# Epoch 44/50
# 10094/10094 [==============================] - 57s 6ms/step - loss: 0.6405 - accuracy: 0.7737 - val_loss: 0.6236 - val_accuracy: 0.7811
# Epoch 45/50
# 10094/10094 [==============================] - 56s 6ms/step - loss: 0.6372 - accuracy: 0.7756 - val_loss: 0.6104 - val_accuracy: 0.7864
# Epoch 46/50
# 10094/10094 [==============================] - 56s 6ms/step - loss: 0.6348 - accuracy: 0.7769 - val_loss: 0.6006 - val_accuracy: 0.7902
# Epoch 47/50
# 10094/10094 [==============================] - 56s 6ms/step - loss: 0.6294 - accuracy: 0.7777 - val_loss: 0.5972 - val_accuracy: 0.7932
# Epoch 48/50
# 10094/10094 [==============================] - 57s 6ms/step - loss: 0.6343 - accuracy: 0.7765 - val_loss: 0.6124 - val_accuracy: 0.7883
# Epoch 49/50
# 10094/10094 [==============================] - 58s 6ms/step - loss: 0.6318 - accuracy: 0.7774 - val_loss: 0.6026 - val_accuracy: 0.7910
# Epoch 50/50
# 10094/10094 [==============================] - 56s 6ms/step - loss: 0.6275 - accuracy: 0.7786 - val_loss: 0.5900 - val_accuracy: 0.7959

# %%
import matplotlib.pyplot as plt
import seaborn as sns  
sns.set_style("whitegrid") 


acc = LSTM_model.history['accuracy']     #获取训练集准确性数据
val_acc = LSTM_model.history['val_accuracy']    #获取验证集准确性数据
loss = LSTM_model.history['loss']          #获取训练集错误值数据
val_loss = LSTM_model.history['val_loss']  #获取验证集错误值数据

epochs = range(1,len(acc)+1)
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(121)
ax1.plot(epochs,acc,'g',label='Trainning acc')     #以epochs为横坐标，以训练集准确性为纵坐标
ax1.plot(epochs,val_acc,'b--',label='Vaildation acc') #以epochs为横坐标，以验证集准确性为纵坐标
ax1.legend()   #绘制图例，即标明图中的线段代表何种含义
plt.ylim(0,1)
ax2 = fig.add_subplot(122)
ax2.plot(epochs,loss,'g',label='Trainning loss')
ax2.plot(epochs,val_loss,'b--',label='Vaildation loss')
ax2.legend()  ##绘制图例，即标明图中的线段代表何种含义
plt.ylim(0,3)
plt.show()

# %%
from sklearn import metrics

predictions = model.predict(X_test)

y_test_pred = np.argmax(predictions, axis=1)
confusion = metrics.ConfusionMatrixDisplay.from_predictions(Y_test,y_test_pred,cmap='Blues',normalize='true',values_format='.2f')
confusion.figure_.suptitle("Confusion Matrix")
confusion.figure_.set_size_inches(8,6)
plt.grid(visible=None)
plt.show()
# Out:
# 911/911 [==============================] - 3s 2ms/step
